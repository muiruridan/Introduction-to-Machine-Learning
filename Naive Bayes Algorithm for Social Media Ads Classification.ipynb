# %% [markdown]
# ## Naive Bayes Algorithm

# %% [markdown]
# ####  It is an algorithm that learns the probability of every object, its features, and which groups they belong to. It is also known as a probabilistic classifier. The Naive Bayes Algorithm comes under supervised learning and is mainly used to solve classification problems.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Importing the required libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import splitting_of_train_test_dataset
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 5
#       3 import matplotlib.pyplot as plt
#       4 import pandas as pd
# ----> 5 from sklearn import splitting_of_train_test_dataset
#       6 from sklearn.preprocessing import StandardScaler
#       7 from sklearn.naive_bayes import GaussianNB
#
# ImportError: cannot import name 'splitting_of_train_test_dataset' from 'sklearn' (C:\Users\muiru\anaconda3\Lib\site-packages\sklearn\__init__.py)
